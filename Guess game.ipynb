# %%
import random

num = random.randint(1,100)

print("WELCOME TO GUESS ME!")
print("I'm thinking of a number between 1 and 100")
print("If your guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess is within 10 of my number, I'll tell you you're WARM")
print("If your guess is farther than your most recent guess, I'll say you're getting COLDER")
print("If your guess is closer than your most recent guess, I'll say you're getting WARMER")
print("LET'S PLAY!")

guesses = [0]

while True:

    # we can copy the code from above to take an input
    guess = int(input("I'm thinking of a number between 1 and 100.\n  What is your guess? "))
    
    if guess < 1 or guess > 100:
        print('OUT OF BOUNDS! Please try again: ')
        continue
    
    # here we compare the player's guess to our number
    if guess == num:
        print(f'CONGRATULATIONS, YOU GUESSED IT IN ONLY {len(guesses)} GUESSES!!')
        break
        
    # if guess is incorrect, add guess to the list
    guesses.append(guess)
    
    # when testing the first guess, guesses[-2]==0, which evaluates to False
    # and brings us down to the second section
    
    if guesses[-2]:  
        if abs(num-guess) < abs(num-guesses[-2]):
            print('WARMER!')
        else:
            print('COLDER!')
   
    else:
        if abs(num-guess) <= 10:
            print('WARM!')
        else:
            print('COLD!')
# Out:
# WELCOME TO GUESS ME!
# I'm thinking of a number between 1 and 100
# If your guess is more than 10 away from my number, I'll tell you you're COLD
# If your guess is within 10 of my number, I'll tell you you're WARM
# If your guess is farther than your most recent guess, I'll say you're getting COLDER
# If your guess is closer than your most recent guess, I'll say you're getting WARMER
# LET'S PLAY!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 22
# WARM!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 13
# COLDER!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 20
# WARMER!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 18
# COLDER!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 21
# WARMER!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 23
# WARMER!
# I'm thinking of a number between 1 and 100.
#   What is your guess? 25
# WARMER!
# ...

# %%
print("WELCOME TO GUESS ME!")
print("I'M THINKING OF A NUMBER BETWEEN 1 AND 100")
print("IF YOUR GUESS IS MORE THAN 10 AWAY FROM MY NUMBER, I'LL TELL YOU'RE COLD")
print("IF YOUR GUESS IS WITHIN 10 OF MY NUMBER I'LL TELL YOU'RE WARM")
print("IF YOUR GUESS IS FURTHER THAN YOUR MOST RECENT GUESS, I'LL SAY YOU'RE COLDER")
print("IF YOUR GUESS IS CLOSER THAN YOUR MOST RECENT GUESS, I'LL SAY YOU'RE GETTING WARMER")
print("LET'S PLAY!")

guesses = [0]

while True:
    guess = int(input("I'm thinking of a number between 1 and 100 .\n What is your guess?"))
    if guess<1 or guess>100:
        print('OUT OF BOUNDS! PLEASE TRY AGAIN')
        continue
        
    if guess == num:
        print(f'CONGRATULATIONS, YOU GUESSED IT IN ONLY {len(guesses)} GUESSES!')
        break 
        
    guesses.append(guess)
    if guesses[-2]:
        if abs(num-guess)< abs(num-guesses[-2]):
            print('WARMER')
        else:
            print('COLDER')
        
    else:
        if abs(num-guess)<=10:
            print("WARM")
        else:
            print("cold")
# Out:
# WELCOME TO GUESS ME!
# I'M THINKING OF A NUMBER BETWEEN 1 AND 100
# IF YOUR GUESS IS MORE THAN 10 AWAY FROM MY NUMBER, I'LL TELL YOU'RE COLD
# IF YOUR GUESS IS WITHIN 10 OF MY NUMBER I'LL TELL YOU'RE WARM
# IF YOUR GUESS IS FURTHER THAN YOUR MOST RECENT GUESS, I'LL SAY YOU'RE COLDER
# IF YOUR GUESS IS CLOSER THAN YOUR MOST RECENT GUESS, I'LL SAY YOU'RE GETTING WARMER
# LET'S PLAY!
# I'm thinking of a number between 1 and 100 .
#  What is your guess?30
# CONGRATULATIONS, YOU GUESSED IT IN ONLY 1 GUESSES!
